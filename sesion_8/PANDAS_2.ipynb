# %% [markdown]
# ## Uniedo Series con  pd.concat()

# %%
#podemos unir series de forma vertical como horizontal usando este método
import pandas as pd
import numpy as np

years=[2010,2011,2012,2013,2014,2015]
PBI=[120,125,148,145,149]

#convirtiendolos en series:

years_serie=pd.Series(years)
PBI_serie=pd.Series(PBI)

# %%
#Verticalmente
data=pd.concat([years_serie, PBI_serie] )
data
# Out:
# 0    2010
# 1    2011
# 2    2012
# 3    2013
# 4    2014
# 5    2015
# 0     120
# 1     125
# 2     148
# 3     145
# 4     149
# dtype: int64

# %%
#Horizontalmente
data=pd.concat([years_serie, PBI_serie], axis=1 )
data.rename(columns={0: "year", 1: "PBI"}, inplace=True) #creamos un Dataframe
data
# Out:
#    year    PBI
# 0  2010  120.0
# 1  2011  125.0
# 2  2012  148.0
# 3  2013  145.0
# 4  2014  149.0
# 5  2015    NaN

# %% [markdown]
# ## OTRAS Formas de obtener un Dataframe

# %% [markdown]
# ### RECOMENDADA: De diccionarios a Dataframe

# %%
data= { 'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
'year': [2000,2001,2002,2001,2002],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}
poblacion = pd.DataFrame(data) #Para crear un dataframe se usa pd.DataFrame()
poblacion
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
#Dataframe con nuestro orden en las columnas
poblacion_2= pd.DataFrame(data, columns=['year', 'state', 'pop'])
poblacion_2
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9

# %%
poblacion_2= pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'])
poblacion_2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN

# %%
#seleccionando una serie de el Dataframe:
poblacion_2['year']   #RECOMENDADO
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# Name: year, dtype: int64

# %%
poblacion_2.state
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# Name: state, dtype: object

# %% [markdown]
# ### Colums

# %%
poblacion_2= pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'])
poblacion_2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN

# %%
## Agregaremos una serie con los valores de la deuda
valores = pd.Series([0,1.2,0, 1.5, 1.7])
valores
# Out:
# 0    0.0
# 1    1.2
# 2    0.0
# 3    1.5
# 4    1.7
# dtype: float64

# %%
poblacion_2['debt'] = valores
poblacion_2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5   0.0
# 1  2001    Ohio  1.7   1.2
# 2  2002    Ohio  3.6   0.0
# 3  2001  Nevada  2.4   1.5
# 4  2002  Nevada  2.9   1.7
